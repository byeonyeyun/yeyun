# %%
#BMI 계산기
kg = float(input('몸무게를 입력해주세요: '))
m = float(input('신장을 입력해주세요: '))
# Out:
# 몸무게를 입력해주세요:  57
# 신장을 입력해주세요:  167

# %%
BMI= (kg/m**2)/100000

# %%
print('당신의 BMI는',round(BMI, 2), '입니다.')
# Out:
# 당신의 BMI는 0.0 입니다.
