# %% [markdown]
# ---
#
#
# # 실습과제 1: 사칙연산 미니 계산기
#
# ---
#
#
# ## 🎯 목표
#
# - 사용자로부터 숫자를 입력받아 사칙연산 계산기를 만들어봅니다.
#
# - 입력값을 int()로 정수형으로 변환합니다.
#
# - 산술 연산자(+, -, *, /)를 사용합니다.
#
# - 조건문(if / elif / else)으로 어떤 연산을 수행할지 분기합니다.
#
# - f-string을 활용해 결과를 보기 좋게 출력합니다.

# %%
# TODO: 사용자로부터 첫 번째 숫자를 입력받으세요
a = int(input("첫 번째 숫자를 입력해주세요: "))
# TODO: 사용자로부터 두 번째 숫자를 입력받으세요
b = int(input("두번째 숫자를 입력해주세요:"))
# TODO: 연산자(+,-,*,/)를 입력받으세요
operator = input("산술 연산자(+,-,*,./)를 입력해주세요")
# TODO: 조건문(if/elif/else)으로 연산을 수행하세요
if operator == "+":
    result = a + b
elif operator == "-":
    result = a - b
elif operator == "*":
    result = a * b
elif operator == "/":
    if num2 != 0:
        result = a / b
    else:
        result = "0으로는 나눌수없습니다."
else:
    result = "잘못된 계산입니다."
# TODO: f-string을 사용하여 결과를 출력하세요
print(f'계산 결과 : {result} 입니다.')
# Out:
# 첫 번째 숫자를 입력해주세요:  2
# 두번째 숫자를 입력해주세요: 1
# 산술 연산자(+,-,*,./)를 입력해주세요 +
# 계산 결과 : 3 입니다.

# %% [markdown]
# ---
#
#
# # 실습과제 2: 온도 단위 변환기
#
# ---
#
#
# ## 🎯 목표
#
# - 사용자로부터 길이와 온도를 입력받아 단위를 변환해봅니다.
#
# - 센티미터 → 미터로 길이를 변환합니다.
#
# - **섭씨(℃) → 화씨(℉)**로 온도를 변환합니다.
#
# - 입력값은 float()로 실수형으로 변환합니다.
#
# - 변환 결과는 f-string을 이용해 보기 좋게 출력합니다.

# %%
# TODO: 사용자로부터 cm 값을 입력받으세요
cm = float(input("cm 값을 입력하세요: "))
# TODO: cm → m 변환 기능을 작성하세요
meter = cm/100
# TODO: 변환 결과를 출력하세요
print(f'{cm}cm는 {meter}m 입니다.')
# TODO: 사용자로부터 섭씨(℃) 값을 입력받으세요
c = float(input("온도를 섭씨값으로 입력해주세요: "))
# TODO: 섭씨 → 화씨 변환 기능을 작성하세요
f = c*9/5+32
# TODO: 변환 결과를 출력하세요
print(f'{c}라는 섭씨 값은 {f}라는 화씨 값으로 변환 됩니다.')
# Out:
# cm 값을 입력하세요:  167
# 167.0cm는 1.67m 입니다.
# 온도를 섭씨값으로 입력해주세요:  36.5
# 36.5라는 섭씨 값은 97.7라는 화씨 값으로 변환 됩니다.
