# %%
# !pip install numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 32.7 MB/s  0:00:00
# ...

# %%
import numpy as np

# %%
weight_kg = [71, 82.5, 65, 90]

# %%
np.array(weight_kg)
# Out:
# array([71. , 82.5, 65. , 90. ])

# %%
weight_kg_np = np.array(weight_kg)

# %%
weight_lb = [ w*2.2 for w in weight_kg]

# %%
weight_lb_np =weight_kg_np * 2.2

# %%
print(weight_lb,weight_lb_np)
# Out:
# [156.20000000000002, 181.50000000000003, 143.0, 198.00000000000003] [156.2 181.5 143.  198. ]
