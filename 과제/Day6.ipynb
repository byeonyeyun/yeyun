# %%
patients = [
    {"name":"철수","age":25},
    {"name":"영희","age":30},
    {"name":"민수","age":17},
]

# TODO: 리스트 컴프리헨션 + 조건
adults = [
    patient.get("name")
    for patient in patients
    if patient.get("age",0 ) >=20
]
